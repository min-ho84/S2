# %%
import os
import joblib
import numpy as np
import pandas as pd
import chardet

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\LS-main\\live'

# %%
os.chdir('../data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\LS-main\\data'

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged.csv',
#  'APT_Merged.xlsx',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'NA_Sample.xlsx',
#  'pivot_table.xlsx',
#  'test.csv',
#  'test.xlsx']

# %% [markdown]
# #### 문자 인코딩 방식 확인 후 csv 파일 불러오자

# %%
fileName = 'APT_Price_Seoul_2020_2022.csv'
with open(file = fileName, mode = 'rb') as file:
    text = file.read()
chardet.detect(text)
# Out:
# {'encoding': 'CP949', 'confidence': 0.99, 'language': 'Korean'}

# %%
price = pd.read_csv('APT_Price_Seoul_2020_2022.csv', encoding = 'CP949')

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139919 entries, 0 to 139918
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지역코드    139919 non-null  int64
#  1   아파트     139919 non-null  object
#  2   시도명     139919 non-null  object
#  3   시군구     139919 non-null  object
#  4   법정동     139919 non-null  object
#  5   지번      139879 non-null  object
#  6   건축년도    139917 non-null  float64
#  7   거래일     139919 non-null  object
#  8   전용면적    139919 non-null  float64
#  9   층       139919 non-null  int64
#  10  거래금액    139919 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 11.7+ MB

# %%
price.head()
# Out:
#     지역코드             아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적
# 0  11110     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1  11110  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2  11110           세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3  11110            킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4  11110        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
#
#     층     거래금액
# 0   6  100,000
# 1   2  162,000
# 2  11   88,000
# 3   4  130,000
# 4   8  149,000

# %% [raw]
# #  0   지역코드    139919 non-null  int64
# # --> 자료형 변경(문자열)하든지, 삭제하든지 결정.
# #  5   지번      139879 non-null  object
# # --> 지번은 수치가 아니고 문자열이 맞다.

# %% [raw]
# #  6   건축년도    139917 non-null  float64 --> 결측값이 있어서 문자열로 변경이 안된다.
# # 결측값은 실수이기 때문에.

# %% [raw]
# #  10  거래금액    139919 non-null  object  --> , 가 있어서 object이고 , 없애야 정수로 변경 가능하다.

# %%
type(price)
# Out:
# pandas.core.frame.DataFrame

# %%
price['지역코드']
# Out:
# 0         11110
# 1         11110
# 2         11110
# 3         11110
# 4         11110
#           ...
# 139914    11740
# 139915    11740
# 139916    11740
# 139917    11740
# 139918    11740
# Name: 지역코드, Length: 139919, dtype: int64

# %%
price[['지역코드']]
# Out:
#          지역코드
# 0       11110
# 1       11110
# 2       11110
# 3       11110
# 4       11110
# ...       ...
# 139914  11740
# 139915  11740
# 139916  11740
# 139917  11740
# 139918  11740
#
# [139919 rows x 1 columns]

# %%
price[['아파트','지역코드']]
# Out:
#                    아파트   지역코드
# 0          신동아블루아광화문의꿈  11110
# 1       광화문스페이스본(106동)  11110
# 2                세종로대우  11110
# 3                 킹스매너  11110
# 4             경희궁파크팰리스  11110
# ...                ...    ...
# 139914           중앙하이츠  11740
# 139915         롯데캐슬퍼스트  11740
# 139916         선사현대아파트  11740
# 139917         파크뷰진도맨션  11740
# 139918       강동리버스트4단지  11740
#
# [139919 rows x 2 columns]

# %%
price.loc[:, ['아파트', '지역코드']]
# Out:
#                    아파트   지역코드
# 0          신동아블루아광화문의꿈  11110
# 1       광화문스페이스본(106동)  11110
# 2                세종로대우  11110
# 3                 킹스매너  11110
# 4             경희궁파크팰리스  11110
# ...                ...    ...
# 139914           중앙하이츠  11740
# 139915         롯데캐슬퍼스트  11740
# 139916         선사현대아파트  11740
# 139917         파크뷰진도맨션  11740
# 139918       강동리버스트4단지  11740
#
# [139919 rows x 2 columns]

# %%
price.head()
# Out:
#     지역코드             아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적
# 0  11110     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1  11110  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2  11110           세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3  11110            킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4  11110        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
#
#     층     거래금액
# 0   6  100,000
# 1   2  162,000
# 2  11   88,000
# 3   4  130,000
# 4   8  149,000

# %%
price['거래일', '거래금액']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('거래일', '거래금액')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
price['거래일']
# Out:
# 0         2020-01-03
# 1         2020-01-02
# 2         2020-01-06
# 3         2020-01-09
# 4         2020-01-20
#              ...
# 139914    2022-12-03
# 139915    2022-12-06
# 139916    2022-12-10
# 139917    2022-12-06
# 139918    2022-12-29
# Name: 거래일, Length: 139919, dtype: object

# %%
price.loc[:, ['거래일', '거래금액']]
# Out:
#                거래일     거래금액
# 0       2020-01-03  100,000
# 1       2020-01-02  162,000
# 2       2020-01-06   88,000
# 3       2020-01-09  130,000
# 4       2020-01-20  149,000
# ...            ...      ...
# 139914  2022-12-03   53,000
# 139915  2022-12-06  135,000
# 139916  2022-12-10   77,000
# 139917  2022-12-06  145,500
# 139918  2022-12-29   55,000
#
# [139919 rows x 2 columns]

# %%
price.dtypes == 'int64'
# Out:
# 지역코드     True
# 아파트     False
# 시도명     False
# 시군구     False
# 법정동     False
# 지번      False
# 건축년도    False
# 거래일     False
# 전용면적    False
# 층        True
# 거래금액    False
# dtype: bool

# %%
price.loc[:, price.dtypes == 'int64']
# Out:
#          지역코드   층
# 0       11110   6
# 1       11110   2
# 2       11110  11
# 3       11110   4
# 4       11110   8
# ...       ...  ..
# 139914  11740   8
# 139915  11740  10
# 139916  11740  17
# 139917  11740  18
# 139918  11740   7
#
# [139919 rows x 2 columns]

# %%
price.loc[:, (price.dtypes == 'int64') | (price.dtypes == 'float64')]
# Out:
#          지역코드    건축년도    전용면적   층
# 0       11110  2007.0  111.97   6
# 1       11110  2008.0  163.33   2
# 2       11110  1994.0  109.91  11
# 3       11110  2004.0  194.43   4
# 4       11110  2003.0  148.09   8
# ...       ...     ...     ...  ..
# 139914  11740  1998.0   59.52   8
# 139915  11740  2008.0  111.22  10
# 139916  11740  2000.0   59.64  17
# 139917  11740  1996.0  208.92  18
# 139918  11740  2020.0   59.99   7
#
# [139919 rows x 4 columns]

# %%
price.dtypes.astype(str)
# Out:
# 지역코드      int64
# 아파트      object
# 시도명      object
# 시군구      object
# 법정동      object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액     object
# dtype: object

# %%
for i in price.dtypes:
    print(type(i))
# Out:
# <class 'numpy.dtype[int64]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[float64]'>
# <class 'numpy.dtype[object_]'>
# <class 'numpy.dtype[float64]'>
# <class 'numpy.dtype[int64]'>
# <class 'numpy.dtype[object_]'>

# %%
for i in price.dtypes.astype(str):
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
price.dtypes.astype(str)
# Out:
# 지역코드      int64
# 아파트      object
# 시도명      object
# 시군구      object
# 법정동      object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액     object
# dtype: object

# %%
price.dtypes.astype(str).isin(values = ['int64', 'float64'])
# price.loc[:,price.dtypes.astype(str).isin(values = ['int64', 'float64'])]
# 같은 결과인데, 위에가 더 좋은 코드이다.
# price.loc[:, (price.dtypes == 'int64') | (price.dtypes == 'float64')]
# Out:
# 지역코드     True
# 아파트     False
# 시도명     False
# 시군구     False
# 법정동     False
# 지번      False
# 건축년도     True
# 거래일     False
# 전용면적     True
# 층        True
# 거래금액    False
# dtype: bool

# %%
price.columns
# Out:
# Index(['지역코드', '아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일', '전용면적', '층',
#        '거래금액'],
#       dtype='object')

# %%
price.columns.str.contains('거래')
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False,  True])

# %%
price.loc[:, price.columns.str.contains('거래')]
# Out:
#                거래일     거래금액
# 0       2020-01-03  100,000
# 1       2020-01-02  162,000
# 2       2020-01-06   88,000
# 3       2020-01-09  130,000
# 4       2020-01-20  149,000
# ...            ...      ...
# 139914  2022-12-03   53,000
# 139915  2022-12-06  135,000
# 139916  2022-12-10   77,000
# 139917  2022-12-06  145,500
# 139918  2022-12-29   55,000
#
# [139919 rows x 2 columns]

# %%
price.drop(['지역코드'], axis = 1) # 안좋은 코드
# Out:
#                    아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1       광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2                세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3                 킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4             경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 139914           중앙하이츠  서울특별시  강동구  암사동  493-14  1998.0  2022-12-03   59.52
# 139915         롯데캐슬퍼스트  서울특별시  강동구  암사동   414-2  2008.0  2022-12-06  111.22
# 139916         선사현대아파트  서울특별시  강동구  암사동     509  2000.0  2022-12-10   59.64
# 139917         파크뷰진도맨션  서울특별시  강동구  성내동   452-2  1996.0  2022-12-06  208.92
# 139918       강동리버스트4단지  서울특별시  강동구  강일동     114  2020.0  2022-12-29   59.99
#
#          층     거래금액
# 0        6  100,000
# ...

# %%
price.drop(columns = ['지역코드']) # 좋은 코드
# Out:
#                    아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1       광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2                세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3                 킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4             경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 139914           중앙하이츠  서울특별시  강동구  암사동  493-14  1998.0  2022-12-03   59.52
# 139915         롯데캐슬퍼스트  서울특별시  강동구  암사동   414-2  2008.0  2022-12-06  111.22
# 139916         선사현대아파트  서울특별시  강동구  암사동     509  2000.0  2022-12-10   59.64
# 139917         파크뷰진도맨션  서울특별시  강동구  성내동   452-2  1996.0  2022-12-06  208.92
# 139918       강동리버스트4단지  서울특별시  강동구  강일동     114  2020.0  2022-12-29   59.99
#
#          층     거래금액
# 0        6  100,000
# ...

# %%
price.head()
# Out:
#     지역코드             아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적
# 0  11110     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1  11110  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2  11110           세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3  11110            킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4  11110        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
#
#     층     거래금액
# 0   6  100,000
# 1   2  162,000
# 2  11   88,000
# 3   4  130,000
# 4   8  149,000

# %%
price = price.drop(columns = ['지역코드'])

# %%
price.dtypes.astype(str).isin(values = ['int64', 'float64'])
# Out:
# 아파트     False
# 시도명     False
# 시군구     False
# 법정동     False
# 지번      False
# 건축년도     True
# 거래일     False
# 전용면적     True
# 층        True
# 거래금액    False
# dtype: bool

# %%
price.head()
# Out:
#               아파트    시도명  시군구  법정동      지번    건축년도         거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09   8
#
#       거래금액
# 0  100,000
# 1  162,000
# 2   88,000
# 3  130,000
# 4  149,000

# %%
price.rename(columns = {'시도명': '시', '시군구': '구', '법정동': '동'})
# Out:
#                    아파트      시    구    동      지번    건축년도         거래일    전용면적
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97  \
# 1       광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33
# 2                세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91
# 3                 킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43
# 4             경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09
# ...                ...    ...  ...  ...     ...     ...         ...     ...
# 139914           중앙하이츠  서울특별시  강동구  암사동  493-14  1998.0  2022-12-03   59.52
# 139915         롯데캐슬퍼스트  서울특별시  강동구  암사동   414-2  2008.0  2022-12-06  111.22
# 139916         선사현대아파트  서울특별시  강동구  암사동     509  2000.0  2022-12-10   59.64
# 139917         파크뷰진도맨션  서울특별시  강동구  성내동   452-2  1996.0  2022-12-06  208.92
# 139918       강동리버스트4단지  서울특별시  강동구  강일동     114  2020.0  2022-12-29   59.99
#
#          층     거래금액
# 0        6  100,000
# ...

# %%
price.columns # 오타방지
# Out:
# Index(['아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액'], dtype='object')

# %%
# price.columns = ['아파트', '시도명', '시군구', '법정동', '지번', '건축년도', '거래일',
#                  '전용면적', '층', '거래금액]

price.columns = ['아파트', '시', '구', '동', '지번', '건축년도',
                 '거래일', '전용면적', '층', '거래금액']
price.columns
# Out:
# Index(['아파트', '시', '구', '동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액'], dtype='object')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번    건축년도         거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0  2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0  2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994.0  2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004.0  2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0  2020-01-20  148.09   8
#
#       거래금액
# 0  100,000
# 1  162,000
# 2   88,000
# 3  130,000
# 4  149,000

# %%
price['거래금액'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 price['거래금액'].astype(float)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
price['거래금액'].str.replace(',','')
# Out:
# 0         100000
# 1         162000
# 2          88000
# 3         130000
# 4         149000
#            ...
# 139914     53000
# 139915    135000
# 139916     77000
# 139917    145500
# 139918     55000
# Name: 거래금액, Length: 139919, dtype: object

# %%
price['거래금액'] = price['거래금액'].str.replace(',','').astype(float)

# %%
price.dtypes
# Out:
# 아파트      object
# 시        object
# 구        object
# 동        object
# 지번       object
# 건축년도    float64
# 거래일      object
# 전용면적    float64
# 층         int64
# 거래금액    float64
# dtype: object

# %%
price = price.astype({'거래일': 'datetime64[ns]', '층': float})

# %%
price.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도           float64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층              float64
# 거래금액           float64
# dtype: object

# %%
cols = ['층', '거래금액']
price[cols]
# Out:
#            층      거래금액
# 0        6.0  100000.0
# 1        2.0  162000.0
# 2       11.0   88000.0
# 3        4.0  130000.0
# 4        8.0  149000.0
# ...      ...       ...
# 139914   8.0   53000.0
# 139915  10.0  135000.0
# 139916  17.0   77000.0
# 139917  18.0  145500.0
# 139918   7.0   55000.0
#
# [139919 rows x 2 columns]

# %%
price[cols] = price[cols].astype(int)

# %%
price.dtypes
# Out:
# 아파트             object
# 시               object
# 구               object
# 동               object
# 지번              object
# 건축년도           float64
# 거래일     datetime64[ns]
# 전용면적           float64
# 층                int32
# 거래금액             int32
# dtype: object

# %%
birth = pd.Series(data = ['1984년 11월 4일'])
birth
# Out:
# 0    1984년 11월 4일
# dtype: object

# %%
birth.astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 birth.astype('datetime64[ns]')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...

# %%
birth = pd.to_datetime(birth, format = '%Y년 %m월 %d일')
birth.iloc[0]
# Out:
# Timestamp('1984-11-04 00:00:00')

# %%
birth.iloc[0].timestamp()
# Out:
# 468374400.0

# %%
today = pd.Timestamp.today()
today
# Out:
# Timestamp('2023-04-13 19:23:46.053919')

# %%
today.timestamp()
# Out:
# 1681413826.053919

# %%
dtGap = today - birth.iloc[0]

# %%
dtGap.days
# Out:
# 14039

# %%
price['거래일'].dt.year
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 139914    2022
# 139915    2022
# 139916    2022
# 139917    2022
# 139918    2022
# Name: 거래일, Length: 139919, dtype: int32

# %%
price['거래일'].dt.month
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 139914    12
# 139915    12
# 139916    12
# 139917    12
# 139918    12
# Name: 거래일, Length: 139919, dtype: int32

# %%
price['거래일'].dt.day
# Out:
# 0          3
# 1          2
# 2          6
# 3          9
# 4         20
#           ..
# 139914     3
# 139915     6
# 139916    10
# 139917     6
# 139918    29
# Name: 거래일, Length: 139919, dtype: int32

# %%
price['거래일'].dt.day_name()
# Out:
# 0           Friday
# 1         Thursday
# 2           Monday
# 3         Thursday
# 4           Monday
#             ...
# 139914    Saturday
# 139915     Tuesday
# 139916    Saturday
# 139917     Tuesday
# 139918    Thursday
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.day_name(locale = 'ko_KR')
# Out:
# 0         금요일
# 1         목요일
# 2         월요일
# 3         목요일
# 4         월요일
#          ...
# 139914    토요일
# 139915    화요일
# 139916    토요일
# 139917    화요일
# 139918    목요일
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.day_name(locale = 'ja_JP')
# Out:
# 0         뗠뾧볷
# 1         뽜뾧볷
# 2         뙉뾧볷
# 3         뽜뾧볷
# 4         뙉뾧볷
#          ...
# 139914    뱘뾧볷
# 139915    됌뾧볷
# 139916    뱘뾧볷
# 139917    됌뾧볷
# 139918    뽜뾧볷
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.day_name(locale = 'en_US')
# Out:
# 0           Friday
# 1         Thursday
# 2           Monday
# 3         Thursday
# 4           Monday
#             ...
# 139914    Saturday
# 139915     Tuesday
# 139916    Saturday
# 139917     Tuesday
# 139918    Thursday
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.strftime('%Y년 %m월 %d일 %A')
# Out:
# 0           2020년 01월 03일 Friday
# 1         2020년 01월 02일 Thursday
# 2           2020년 01월 06일 Monday
# 3         2020년 01월 09일 Thursday
# 4           2020년 01월 20일 Monday
#                    ...
# 139914    2022년 12월 03일 Saturday
# 139915     2022년 12월 06일 Tuesday
# 139916    2022년 12월 10일 Saturday
# 139917     2022년 12월 06일 Tuesday
# 139918    2022년 12월 29일 Thursday
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.strftime('%Y년 %m월 %d일 %a')
# Out:
# 0         2020년 01월 03일 Fri
# 1         2020년 01월 02일 Thu
# 2         2020년 01월 06일 Mon
# 3         2020년 01월 09일 Thu
# 4         2020년 01월 20일 Mon
#                 ...
# 139914    2022년 12월 03일 Sat
# 139915    2022년 12월 06일 Tue
# 139916    2022년 12월 10일 Sat
# 139917    2022년 12월 06일 Tue
# 139918    2022년 12월 29일 Thu
# Name: 거래일, Length: 139919, dtype: object

# %%
price['거래일'].dt.strftime('%w-%a')  # 오름차순, 내림차순 정렬을 위해 요일을 정수로 변환하는 것이 좋다.
# Out:
# 0         5-Fri
# 1         4-Thu
# 2         1-Mon
# 3         4-Thu
# 4         1-Mon
#           ...
# 139914    6-Sat
# 139915    2-Tue
# 139916    6-Sat
# 139917    2-Tue
# 139918    4-Thu
# Name: 거래일, Length: 139919, dtype: object

# %%
# df1 = price[price['거래금액'] >= 1200000]
# df1

# %%
price.loc[price['거래금액'] >= 1200000]
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
price[price['아파트'] == '한남더힐']
# Out:
#          아파트      시    구    동   지번    건축년도        거래일     전용면적   층     거래금액
# 239     한남더힐  서울특별시  용산구  한남동  810  2011.0 2020-01-13  235.312   2   480000
# 240     한남더힐  서울특별시  용산구  한남동  810  2011.0 2020-01-16  208.478   7   455000
# 245     한남더힐  서울특별시  용산구  한남동  810  2011.0 2020-01-29  235.312  10   480000
# 6733    한남더힐  서울특별시  용산구  한남동  810  2011.0 2020-02-17  240.230   5   660000
# 6734    한남더힐  서울특별시  용산구  한남동  810  2011.0 2020-02-18  240.230   4   645000
# ...      ...    ...  ...  ...  ...     ...        ...      ...  ..      ...
# 133114  한남더힐  서울특별시  용산구  한남동  810  2011.0 2022-05-17   59.686   5   300000
# 133118  한남더힐  서울특별시  용산구  한남동  810  2011.0 2022-05-30  240.305   3  1100000
# 134898  한남더힐  서울특별시  용산구  한남동  810  2011.0 2022-06-09  235.312   1   850000
# 134899  한남더힐  서울특별시  용산구  한남동  810  2011.0 2022-06-17  235.312   6   800000
# 136011  한남더힐  서울특별시  용산구  한남동  810  2011.0 2022-07-21  235.312   3   890000
#
# [84 rows x 10 columns]

# %%
df1 = price[price['거래금액'] >= 1200000]
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df2 = price[(price['거래금액'] < 1200000) & (price['층'] >= 65)]
df2
# Out:
#             아파트      시    구    동      지번    건축년도        거래일     전용면적   층
# 50867   현대하이페리온  서울특별시  양천구   목동     916  2003.0 2020-07-03  154.050  66  \
# 55000    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-07-25  235.740  67
# 69573    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-10-27  185.622  66
# 110650   타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2021-06-24  214.967  66
#
#           거래금액
# 50867   240000
# 55000   542500
# 69573   380000
# 110650  458000

# %%
price['거래금액'].lt(1200000) & price['층'].ge(65)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Length: 139919, dtype: bool

# %%
df2 = price[price['거래금액'].lt(1200000) & price['층'].ge(65)]
df2
# Out:
#             아파트      시    구    동      지번    건축년도        거래일     전용면적   층
# 50867   현대하이페리온  서울특별시  양천구   목동     916  2003.0 2020-07-03  154.050  66  \
# 55000    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-07-25  235.740  67
# 69573    타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2020-10-27  185.622  66
# 110650   타워팰리스3  서울특별시  강남구  도곡동  467-29  2004.0 2021-06-24  214.967  66
#
#           거래금액
# 50867   240000
# 55000   542500
# 69573   380000
# 110650  458000

# %%
price['층'].gt(65).sum()
# Out:
# 4

# %%
price['층'].ge(65).sum()
# Out:
# 4

# %%
price['층'].lt(65).sum()
# Out:
# 139915

# %%
price['층'].le(65).sum()

# %%
price['층'].eq(65).sum()
# Out:
# 0

# %%
price['층'].ne(65).sum()
# Out:
# 139919

# %%
(price['거래금액'] < 1200000) & (price['층'] >= 65)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Length: 139919, dtype: bool

# %%
price['거래금액'].lt(1200000) & price['층'].ge(65)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Length: 139919, dtype: bool

# %%
# 구가 강남구인 행을 선택해 보세요.

# %%
price.head()
# Out:
#               아파트      시    구    동      지번    건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994.0 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004.0 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0 2020-01-20  148.09   8
#
#      거래금액
# 0  100000
# 1  162000
# 2   88000
# 3  130000
# 4  149000

# %%
price[price['구'].eq('강남구')]
# Out:
#              아파트      시    구    동      지번    건축년도        거래일     전용면적   층
# 5819       현대하이츠  서울특별시  강남구  역삼동  775-15  2004.0 2020-01-03   99.220   4  \
# 5820     우림루미아트1  서울특별시  강남구  역삼동  706-11  2003.0 2020-01-03   24.000   8
# 5821    한스빌(836)  서울특별시  강남구  역삼동     836  1996.0 2020-01-04   41.950  11
# 5822      동부센트레빌  서울특별시  강남구  역삼동     716  1998.0 2020-01-06   59.820  21
# 5823     강남서해더블루  서울특별시  강남구  역삼동  796-29  2012.0 2020-01-06   62.260  10
# ...          ...    ...  ...  ...     ...     ...        ...      ...  ..
# 139839      목련타운  서울특별시  강남구  일원동     716  1993.0 2022-12-09  134.710  14
# 139840      목련타운  서울특별시  강남구  일원동     716  1993.0 2022-12-12  134.710   6
# 139841       신동아  서울특별시  강남구  수서동     736  1992.0 2022-12-10   39.510  13
# 139842    대림아크로빌  서울특별시  강남구  도곡동   467-6  1999.0 2022-12-09  177.255  22
# 139843    대림아크로빌  서울특별시  강남구  도곡동   467-6  1999.0 2022-12-15  172.467  31
#
#           거래금액
# 5819     77000
# 5820     20200
# 5821     39500
# ...

# %%
price[price['구'].eq('강남구')].shape[0]
# Out:
# 6723

# %%
price[price['구'].eq('강남구')].shape
# Out:
# (6723, 10)

# %%
# 구가 강남구 또는 서초구인 행을 선택해 보세요.

# %%
price[price['구'].eq('강남구') | price['구'].eq('서초구')]
# Out:
#             아파트      시    구    동      지번    건축년도        거래일      전용면적   층
# 5696    삼호1동~3동  서울특별시  서초구  방배동   770-1  1975.0 2020-01-03   81.3900   5  \
# 5697    롯데캐슬아르떼  서울특별시  서초구  방배동  424-28  2013.0 2020-01-03  121.6356  12
# 5698      신한엔시모  서울특별시  서초구  방배동   802-4  2005.0 2020-01-03  244.2000   3
# 5699    삼호1동~3동  서울특별시  서초구  방배동   770-1  1975.0 2020-01-07  116.1300  12
# 5700     방배브라운가  서울특별시  서초구  방배동   930-1  2006.0 2020-01-08   84.9400  10
# ...         ...    ...  ...  ...     ...     ...        ...       ...  ..
# 139839     목련타운  서울특별시  강남구  일원동     716  1993.0 2022-12-09  134.7100  14
# 139840     목련타운  서울특별시  강남구  일원동     716  1993.0 2022-12-12  134.7100   6
# 139841      신동아  서울특별시  강남구  수서동     736  1992.0 2022-12-10   39.5100  13
# 139842   대림아크로빌  서울특별시  강남구  도곡동   467-6  1999.0 2022-12-09  177.2550  22
# 139843   대림아크로빌  서울특별시  강남구  도곡동   467-6  1999.0 2022-12-15  172.4670  31
#
#           거래금액
# 5696    127500
# 5697    209000
# 5698    197500
# ...

# %%
# 구가 강남구, 서초구 또는 송파구인 행을 선택해 보세요.

# %%
price[price['구'].eq('강남구') | price['구'].eq('서초구') | price['구'].eq('송파구')].shape[0]

# %%
price[price['구'].isin(values = ['강남구', '서초구', '송파구'])].shape[0]
# Out:
# 20349

# %%
price[price['구'].str.contains('강남|서초|송파')].shape[0] # good 코딩
# Out:
# 20349

# %%
price[price['구'].str.contains('^강')].shape[0]
# Out:
# 26225

# %%
price[price['구'].str.contains('동')].shape[0] # '동' 이 포함된 전부
# Out:
# 22248

# %%
price[price['구'].str.contains('^동')].shape[0] # '동'으로 시작하는 것
# Out:
# 10527

# %%
price[price['구'].str.contains('.동')].shape[0] # 앞글자는 모르겠지만 두번째 글자가 동인
# Out:
# 11721

# %%
price[price['구'].str.contains('..구')].shape[0]
# Out:
# 138084

# %%
addr = pd.Series(data = ['서울특별시 강남구', '경기도 성남시 분당구', '인천광역시 중구'])

# %%
addr
# Out:
# 0      서울특별시 강남구
# 1    경기도 성남시 분당구
# 2       인천광역시 중구
# dtype: object

# %%
addr.str.split(' ') # 시리즈로 반환
# Out:
# 0       [서울특별시, 강남구]
# 1    [경기도, 성남시, 분당구]
# 2        [인천광역시, 중구]
# dtype: object

# %%
addr.str.split(' ', expand = True) # 데이터프레임으로 반환
# Out:
#        0    1     2
# 0  서울특별시  강남구  None
# 1    경기도  성남시   분당구
# 2  인천광역시   중구  None

# %%
addr
# Out:
# 0      서울특별시 강남구
# 1    경기도 성남시 분당구
# 2       인천광역시 중구
# dtype: object

# %%
addr.str.find('시')
# Out:
# 0    4
# 1    6
# 2    4
# dtype: int64

# %%
addr.str.find('도')
# Out:
# 0   -1
# 1    2
# 2   -1
# dtype: int64

# %%
addr.str.slice(0, 2)
# Out:
# 0    서울
# 1    경기
# 2    인천
# dtype: object

# %%
addr
# Out:
# 0      서울특별시 강남구
# 1    경기도 성남시 분당구
# 2       인천광역시 중구
# dtype: object

# %%
addr.str.extract('(.+시)')
# Out:
#          0
# 0    서울특별시
# 1  경기도 성남시
# 2    인천광역시

# %%
addr.str.extract(' (.+구)')
# Out:
#          0
# 0      강남구
# 1  성남시 분당구
# 2       중구

# %%
addr.str.extract('([가-힣]+구)')
# Out:
#      0
# 0  강남구
# 1  분당구
# 2   중구

# %%
addr.str.extract('([남]+구)')
# Out:
#      0
# 0   남구
# 1  NaN
# 2  NaN

# %%
df1 = price[price['거래금액'] >= 1200000]
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df1.drop(index = [126596, 131285])
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16  \
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 132781  1450000
# 137420  1300000

# %%
df1.index
# Out:
# Index([126596, 131285, 132781, 137420], dtype='int64')

# %%
df1.drop(index = df1.index[0:2])
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16  \
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 132781  1450000
# 137420  1300000

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df1
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#            거래금액
# 126596  1200000
# 131285  1350000
# 132781  1450000
# 137420  1300000

# %%
df1.reset_index()
# Out:
#     index        아파트      시    구      동       지번    건축년도        거래일     전용면적
# 0  126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950  \
# 1  131285      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670
# 2  132781      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960
# 3  137420  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546
#
#     층     거래금액
# 0   2  1200000
# 1   5  1350000
# 2  16  1450000
# 3  47  1300000

# %%
df1.reset_index(drop = True) # 기존 인덱스 날려버리는 방법
# Out:
#          아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 0      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 1      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 2      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#       거래금액
# 0  1200000
# 1  1350000
# 2  1450000
# 3  1300000

# %%
df1.set_index(keys = ['아파트'])

# %%
df1 = df1.set_index(keys = ['아파트', '시', '구', '동'])

# %%
df1
# Out:
#                                 지번    건축년도        거래일     전용면적   층     거래금액
# 아파트       시     구   동
# 파르크한남     서울특별시 용산구 한남동        410  2020.0 2021-12-13  268.950   2  1200000
#                     한남동        410  2020.0 2022-04-30  268.670   5  1350000
# PH129     서울특별시 강남구 청담동        129  2020.0 2022-04-28  273.960  16  1450000
# 아크로서울포레스트 서울특별시 성동구 성수동1가  685-700  2020.0 2022-09-30  264.546  47  1300000

# %%
df1.reset_index()
# Out:
#          아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 0      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 1      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 2      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#       거래금액
# 0  1200000
# 1  1350000
# 2  1450000
# 3  1300000

# %%
df1 = df1.reset_index()
df1
# Out:
#          아파트      시    구      동       지번    건축년도        거래일     전용면적   층
# 0      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950   2  \
# 1      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670   5
# 2      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960  16
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546  47
#
#       거래금액
# 0  1200000
# 1  1350000
# 2  1450000
# 3  1300000

# %%
price.isna()
# Out:
#           아파트      시      구      동     지번   건축년도    거래일   전용면적      층   거래금액
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 139914  False  False  False  False  False  False  False  False  False  False
# 139915  False  False  False  False  False  False  False  False  False  False
# 139916  False  False  False  False  False  False  False  False  False  False
# 139917  False  False  False  False  False  False  False  False  False  False
# 139918  False  False  False  False  False  False  False  False  False  False
#
# [139919 rows x 10 columns]

# %%
price.isna().sum()  # 아주 쉽게 결측있는 열과 수량 확인 가능
# Out:
# 아파트      0
# 시        0
# 구        0
# 동        0
# 지번      40
# 건축년도     2
# 거래일      0
# 전용면적     0
# 층        0
# 거래금액     0
# dtype: int64

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139919 entries, 0 to 139918
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     139919 non-null  object
#  1   시       139919 non-null  object
#  2   구       139919 non-null  object
#  3   동       139919 non-null  object
#  4   지번      139879 non-null  object
#  5   건축년도    139917 non-null  float64
#  6   거래일     139919 non-null  datetime64[ns]
#  7   전용면적    139919 non-null  float64
#  8   층       139919 non-null  int32
#  9   거래금액    139919 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), object(5)
# memory usage: 9.6+ MB

# %%
price[price['지번'].isna()]
# Out:
#                   아파트      시    구    동   지번    건축년도        거래일    전용면적   층
# 5817    힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-01-20   84.99   3  \
# 5818    힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-01-23   84.95   1
# 13920       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-02-08   59.21  13
# 13925   힐스테이트 서초 젠트리스  서울특별시  서초구  신원동  NaN  2014.0 2020-02-22  114.90   1
# 19081       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-03-07   84.48  20
# 42068       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-06-13   84.48  14
# 42079       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-06-30   84.87  14
# 54592       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-07-05   84.48  14
# 54593       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-07-05   84.48  14
# 54595       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-07-06   84.87  15
# 54603       서초포레스타2단지  서울특별시  서초구  내곡동  NaN  2015.0 2020-07-11   84.48   5
# ...

# %%
price['아파트'].eq('서초포레스타2단지')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Name: 아파트, Length: 139919, dtype: bool

# %%
price.loc[price['아파트'].eq('서초포레스타2단지'), '지번'] = '384'
price.loc[price['아파트'].eq('힐스테이트 서초 젠트리스'), '지번'] = '557'

# %%
price.isna().sum()
# Out:
# 아파트     0
# 시       0
# 구       0
# 동       0
# 지번      0
# 건축년도    2
# 거래일     0
# 전용면적    0
# 층       0
# 거래금액    0
# dtype: int64

# %%
price['건축년도'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Name: 건축년도, Length: 139919, dtype: bool

# %%
price[price['건축년도'].isna()]
# Out:
#               아파트      시    구    동  지번  건축년도        거래일   전용면적  층    거래금액
# 128072  DMCSKVIEW  서울특별시  은평구  수색동  30   NaN 2022-01-28  84.99  7  140000
# 129140  DMCSKVIEW  서울특별시  은평구  수색동  30   NaN 2022-02-10  84.99  6  137000

# %%
price[price['건축년도'].isna()].fillna(value = '-')
# Out:
#               아파트      시    구    동  지번 건축년도        거래일   전용면적  층    거래금액
# 128072  DMCSKVIEW  서울특별시  은평구  수색동  30    - 2022-01-28  84.99  7  140000
# 129140  DMCSKVIEW  서울특별시  은평구  수색동  30    - 2022-02-10  84.99  6  137000

# %%
price[price['건축년도'].isna()].fillna(value = 9999)
# Out:
#               아파트      시    구    동  지번    건축년도        거래일   전용면적  층    거래금액
# 128072  DMCSKVIEW  서울특별시  은평구  수색동  30  9999.0 2022-01-28  84.99  7  140000
# 129140  DMCSKVIEW  서울특별시  은평구  수색동  30  9999.0 2022-02-10  84.99  6  137000

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged.csv',
#  'APT_Merged.xlsx',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'NA_Sample.xlsx',
#  'pivot_table.xlsx',
#  'test.csv',
#  'test.xlsx']

# %%
na = pd.read_excel('NA_Sample.xlsx')

# %%
na
# Out:
#     구분 항목    값
# 0    A  a  1.2
# 1  NaN  b  2.3
# 2  NaN  c  3.5
# 3    B  a  1.7
# 4  NaN  b  2.6
# 5  NaN  c  3.6

# %%
na.fillna(method = 'ffill')
# Out:
#   구분 항목    값
# 0  A  a  1.2
# 1  A  b  2.3
# 2  A  c  3.5
# 3  B  a  1.7
# 4  B  b  2.6
# 5  B  c  3.6

# %%
na.fillna(method = 'bfill')  # 거의 쓸일이 없다.
# Out:
#     구분 항목    값
# 0    A  a  1.2
# 1    B  b  2.3
# 2    B  c  3.5
# 3    B  a  1.7
# 4  NaN  b  2.6
# 5  NaN  c  3.6

# %%
price.dropna()

# %%
price[price['건축년도'].isna()]

# %%
price[~price['건축년도'].isna()]

# %%
price['건축년도'].astype(int)

# %%
price = price[price['건축년도'].notna()]
price
# Out:
#                    아파트      시    구    동      지번    건축년도        거래일    전용면적
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007.0 2020-01-03  111.97  \
# 1       광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008.0 2020-01-02  163.33
# 2                세종로대우  서울특별시  종로구  내수동     167  1994.0 2020-01-06  109.91
# 3                 킹스매너  서울특별시  종로구  내수동  110-15  2004.0 2020-01-09  194.43
# 4             경희궁파크팰리스  서울특별시  종로구  내수동      95  2003.0 2020-01-20  148.09
# ...                ...    ...  ...  ...     ...     ...        ...     ...
# 139914           중앙하이츠  서울특별시  강동구  암사동  493-14  1998.0 2022-12-03   59.52
# 139915         롯데캐슬퍼스트  서울특별시  강동구  암사동   414-2  2008.0 2022-12-06  111.22
# 139916         선사현대아파트  서울특별시  강동구  암사동     509  2000.0 2022-12-10   59.64
# 139917         파크뷰진도맨션  서울특별시  강동구  성내동   452-2  1996.0 2022-12-06  208.92
# 139918       강동리버스트4단지  서울특별시  강동구  강일동     114  2020.0 2022-12-29   59.99
#
#          층    거래금액
# 0        6  100000
# 1        2  162000
# ...

# %%
price['건축년도'].dtype
# Out:
# dtype('float64')

# %%
price['건축년도'] = price['건축년도'].astype(int) ## 이상해요. Warning 메세지입니다. 코드 -> 미래에는 안될꺼야

# %%
price['거래금액']
# Out:
# 0         100000
# 1         162000
# 2          88000
# 3         130000
# 4         149000
#            ...
# 139914     53000
# 139915    135000
# 139916     77000
# 139917    145500
# 139918     55000
# Name: 거래금액, Length: 139917, dtype: int32

# %%
price['평당금액'] = price['거래금액'] / price['전용면적'] * 3.3

# %%
# %precision 3
# Out:
# '%.3f'

# %%
pd.reset_option('display.precision')

# %%
pd.set_option('display.precision', 3)

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#      거래금액      평당금액
# 0  100000  2947.218
# 1  162000  3273.128
# 2   88000  2642.162
# 3  130000  2206.450
# 4  149000  3320.278

# %%
price['거래금액'] = price['거래금액'] / 1000

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#     거래금액      평당금액
# 0  100.0  2947.218
# 1  162.0  3273.128
# 2   88.0  2642.162
# 3  130.0  2206.450
# 4  149.0  3320.278

# %%
price['거래년도'] = price['거래일'].dt.year

# %%
price['경과년수'] = price['거래년도'] - price['건축년도']

# %%
price['거래월'] = price['거래일'].dt.strftime('%m월')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#     거래금액      평당금액  거래년도  경과년수  거래월
# 0  100.0  2947.218  2020    13  01월
# 1  162.0  3273.128  2020    12  01월
# 2   88.0  2642.162  2020    26  01월
# 3  130.0  2206.450  2020    16  01월
# 4  149.0  3320.278  2020    17  01월

# %%
locs = price['평당금액'].ge(5000)
locs
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139914    False
# 139915    False
# 139916    False
# 139917    False
# 139918    False
# Name: 평당금액, Length: 139917, dtype: bool

# %%
np.where(locs, '5천 이상', '5천 미만')
# Out:
# array(['5천 미만', '5천 미만', '5천 미만', ..., '5천 미만', '5천 미만', '5천 미만'],
#       dtype='<U5')

# %%
price['금액구간'] = np.where(locs, '5천 이상', '5천 미만')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#     거래금액      평당금액  거래년도  경과년수  거래월   금액구간
# 0  100.0  2947.218  2020    13  01월  5천 미만
# 1  162.0  3273.128  2020    12  01월  5천 미만
# 2   88.0  2642.162  2020    26  01월  5천 미만
# 3  130.0  2206.450  2020    16  01월  5천 미만
# 4  149.0  3320.278  2020    17  01월  5천 미만

# %%
np.where(locs)  ## 인덱스 반환
# Out:
# (array([    52,     53,    148, ..., 139900, 139903, 139905], dtype=int64),)

# %%
price['주소'] = price['시'] + ' ' + price['구'] + ' ' + \
                price['동'] + ' ' + price['지번']

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  \
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#     거래금액      평당금액  거래년도  경과년수  거래월   금액구간                    주소
# 0  100.0  2947.218  2020    13  01월  5천 미만     서울특별시 종로구 필운동 254
# 1  162.0  3273.128  2020    12  01월  5천 미만     서울특별시 종로구 사직동 9-1
# 2   88.0  2642.162  2020    26  01월  5천 미만     서울특별시 종로구 내수동 167
# 3  130.0  2206.450  2020    16  01월  5천 미만  서울특별시 종로구 내수동 110-15
# 4  149.0  3320.278  2020    17  01월  5천 미만      서울특별시 종로구 내수동 95

# %%
cols = ['시', '동', '지번']

# %%
type(cols)
# Out:
# list

# %%
price[cols].apply(func = lambda x: ' '.join(x), axis = 1)
# Out:
# 0            서울특별시 필운동 254
# 1            서울특별시 사직동 9-1
# 2            서울특별시 내수동 167
# 3         서울특별시 내수동 110-15
# 4             서울특별시 내수동 95
#                 ...
# 139914    서울특별시 암사동 493-14
# 139915     서울특별시 암사동 414-2
# 139916       서울특별시 암사동 509
# 139917     서울특별시 성내동 452-2
# 139918       서울특별시 강일동 114
# Length: 139917, dtype: object

# %% [markdown]
# ## 중요 합니다.!!!!

# %%
price[cols].apply(func = len, axis = 1)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 139914    3
# 139915    3
# 139916    3
# 139917    3
# 139918    3
# Length: 139917, dtype: int64

# %%
price[cols].apply(func = len, axis = 0)
# Out:
# 시     139917
# 동     139917
# 지번    139917
# dtype: int64

# %%
price['아파트']
# Out:
# 0            신동아블루아광화문의꿈
# 1         광화문스페이스본(106동)
# 2                  세종로대우
# 3                   킹스매너
# 4               경희궁파크팰리스
#                ...
# 139914             중앙하이츠
# 139915           롯데캐슬퍼스트
# 139916           선사현대아파트
# 139917           파크뷰진도맨션
# 139918         강동리버스트4단지
# Name: 아파트, Length: 139917, dtype: object

# %%
price['아파트'].map(arg = len)  ## 시리즈의 원소마다 실행하는 것
# Out:
# 0         11
# 1         14
# 2          5
# 3          4
# 4          8
#           ..
# 139914     5
# 139915     7
# 139916     7
# 139917     7
# 139918     9
# Name: 아파트, Length: 139917, dtype: int64

# %%
price[cols]
# Out:
#             시    동      지번
# 0       서울특별시  필운동     254
# 1       서울특별시  사직동     9-1
# 2       서울특별시  내수동     167
# 3       서울특별시  내수동  110-15
# 4       서울특별시  내수동      95
# ...       ...  ...     ...
# 139914  서울특별시  암사동  493-14
# 139915  서울특별시  암사동   414-2
# 139916  서울특별시  암사동     509
# 139917  서울특별시  성내동   452-2
# 139918  서울특별시  강일동     114
#
# [139917 rows x 3 columns]

# %%
price[cols].applymap(func = len)

# %%
import seaborn as sns
from scipy import stats

# %%
data = sns.load_dataset(name = 'iris')
data

# %%
data.columns

# %%
cols = ['sepal_width', 'petal_length', 'petal_width']
data[cols]

# %%
stats.pearsonr(x = data['sepal_width'], y = data['sepal_length'])[1]

# %%
lambda x : stats.pearsonr(x = x, y = data['sepal_length'])[1]

# %%
data[cols].apply(func =lambda x : stats.pearsonr(x = x, y = data['sepal_length'])[1])

# %%
corr = lambda x : stats.pearsonr(x = x, y = data['sepal_length'])[1]

# %%
data[cols].apply(func = corr)

# %%
price['층'].sort_values()
# Out:
# 17278     -3
# 49742     -3
# 31734     -2
# 49607     -2
# 29747     -2
#           ..
# 122507    64
# 69573     66
# 110650    66
# 50867     66
# 55000     67
# Name: 층, Length: 139917, dtype: int32

# %%
price['층'].sort_values(ascending = False)
# Out:
# 55000     67
# 110650    66
# 50867     66
# 69573     66
# 137287    64
#           ..
# 49607     -2
# 45769     -2
# 52683     -2
# 17278     -3
# 49742     -3
# Name: 층, Length: 139917, dtype: int32

# %%
price.sort_values(by = ['층'])
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510  \
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
# 31734            롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27   59.895
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# 29747     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-06-30   76.660
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 122507             타워팰리스1  서울특별시  강남구  도곡동     467  2002 2021-09-30  222.480
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740
#
# ...

# %%
price.sort_values(by = ['층'], ascending = False)
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740  \
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 137287             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2022-08-29  244.224
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# 45769     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30  107.990
# 52683           천왕연지타운2단지  서울특별시  구로구  천왕동     281  2014 2020-07-02   84.780
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
#
# ...

# %%
price.sort_values(by = ['층', '거래금액'])
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510  \
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
# 52683           천왕연지타운2단지  서울특별시  구로구  천왕동     281  2014 2020-07-02   84.780
# 31734            롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27   59.895
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 137287             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2022-08-29  244.224
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740
#
# ...

# %%
price.sort_values(by = ['층', '거래금액'], ascending = [False, True])
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740  \
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 93843              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-02-10  214.967
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# 29747     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-06-30   76.660
# 45769     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30  107.990
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
#
# ...

# %%
price.sort_values(by = ['평당금액'], ascending = False)
# Out:
#               아파트      시    구    동       지번  건축년도        거래일    전용면적   층
# 135785  아크로리버뷰신반포  서울특별시  서초구  잠원동      159  2018 2022-06-24   78.50  26  \
# 135800    반포주공1단지  서울특별시  서초구  반포동      757  1973 2022-06-29  107.47   3
# 128654    아크로리버파크  서울특별시  서초구  반포동     2-12  2016 2022-01-21   84.95   8
# 19105     개포주공1단지  서울특별시  강남구  개포동      141  1982 2020-03-04   56.57   4
# 13976     개포주공1단지  서울특별시  강남구  개포동      141  1982 2020-02-17   58.08   4
# ...           ...    ...  ...  ...      ...   ...        ...     ...  ..
# 32384        화계맨숀  서울특별시  강북구  수유동   461-13  1975 2020-06-03   50.91   3
# 24112        화계맨숀  서울특별시  강북구  수유동   461-13  1975 2020-05-20   58.51   5
# 12271    청우아트빌라3차  서울특별시  구로구  구로동    740-9  1994 2020-02-29   42.30   1
# 66647          로얄  서울특별시  도봉구  쌍문동   357-14  2000 2020-10-23   42.00  -1
# 65569       인성아트빌  서울특별시   중구  신당동  432-502  2001 2020-10-12   58.11  -1
#
#          거래금액       평당금액  거래년도  경과년수  거래월   금액구간                    주소
# ...

# %%
price['거래금액'].count()
# Out:
# 139917

# %%
price['거래금액'].sum()
# Out:
# 12778739.269

# %%
price['거래금액'].mean()
# Out:
# 91.331

# %%
price['거래금액'].std()
# Out:
# 67.479

# %%
price['거래금액'].min()
# Out:
# 6.000

# %%
price['거래금액'].max()
# Out:
# 1450.000

# %%
type(price.groupby(by = ['거래년도'])['거래금액'])
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
price.groupby(by = ['거래년도'])['거래금액'].count()
# Out:
# 거래년도
# 2020    84294
# 2021    43420
# 2022    12203
# Name: 거래금액, dtype: int64

# %%
price.groupby(by = ['거래년도'])['거래금액'].sum()
# Out:
# 거래년도
# 2020    7.130e+06
# 2021    4.459e+06
# 2022    1.189e+06
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].mean()
# Out:
# 거래년도
# 2020     84.589
# 2021    102.702
# 2022     97.443
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].std()
# Out:
# 거래년도
# 2020    56.837
# 2021    75.100
# 2022    94.951
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].min()
# Out:
# 거래년도
# 2020    6.0
# 2021    6.6
# 2022    6.7
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].max()
# Out:
# 거래년도
# 2020     775.0
# 2021    1200.0
# 2022    1450.0
# Name: 거래금액, dtype: float64

# %%
pd.pivot_table(
    data = price,
    values = '거래금액',
    index = '구',
    columns = None,
    aggfunc = np.mean
)
# Out:
#          거래금액
# 구
# 강남구   195.461
# 강동구    86.880
# 강북구    58.530
# 강서구    71.057
# 관악구    65.551
# 광진구   110.670
# 구로구    56.449
# 금천구    50.917
# 노원구    57.333
# 도봉구    49.850
# 동대문구   73.029
# 동작구   100.522
# 마포구   106.718
# 서대문구   82.785
# 서초구   189.398
# 성동구   126.190
# 성북구    73.076
# 송파구   139.153
# 양천구    94.234
# 영등포구   92.670
# 용산구   174.441
# 은평구    65.852
# 종로구    82.830
# 중구     89.706
# 중랑구    55.052

# %%
pd.pivot_table(
    data = price,
    values = '거래금액',
    index = '구',
    columns = '거래년도',
    aggfunc = np.mean
)
# Out:
# 거래년도     2020     2021     2022
# 구
# 강남구   183.946  207.287  216.955
# 강동구    83.809   93.626   85.345
# 강북구    55.942   66.961   50.294
# 강서구    67.700   79.184   65.282
# 관악구    61.852   72.921   63.098
# 광진구   106.705  119.721  104.692
# 구로구    54.440   62.033   50.505
# 금천구    47.038   59.569   46.061
# 노원구    52.201   67.274   65.438
# 도봉구    45.698   58.488   56.334
# 동대문구   71.174   77.632   69.418
# 동작구    97.779  111.737   83.120
# 마포구   101.333  116.832  105.554
# 서대문구   78.567   90.763   82.926
# 서초구   174.956  204.788  210.655
# 성동구   114.341  144.546  148.837
# 성북구    66.859   84.096   77.207
# 송파구   130.260  154.335  152.301
# 양천구    89.062  103.119   97.303
# 영등포구   89.751  101.855   81.305
# 용산구   152.303  199.106  220.268
# 은평구    62.445   73.170   64.711
# 종로구    80.061   92.995   68.429
# 중구     92.392   90.002   74.541
# 중랑구    50.934   64.463   48.483

# %%
pd.pivot_table(
    data = price,
    values = '거래금액',
    index = ['구','동'],
    columns = '거래년도',
    aggfunc = np.mean
)

# %%
pd.pivot_table(
    data = price,
    values = '거래금액',
    index = ['구','동'],
    columns = '거래년도',
    aggfunc = [np.size, np.mean, np.std]
)

# %%
pd.pivot_table(
    data = price,
    values = '거래금액',
    index = ['구','동'],
    columns = '거래년도',
    aggfunc = [np.size, np.mean, np.std]
).to_excel('pivot_table.xlsx')

# %%
price['구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
price['구'].nunique()
# Out:
# 25

# %%
price['구'].value_counts()
# Out:
# 구
# 노원구     13909
# 강서구      9322
# 구로구      8491
# 송파구      7432
# 성북구      7386
# 도봉구      6876
# 강동구      6801
# 강남구      6723
# 서초구      6194
# 영등포구     5998
# 양천구      5793
# 은평구      5724
# 동대문구     5496
# 중랑구      5089
# 동작구      5031
# 성동구      4920
# 마포구      4849
# 관악구      4604
# 서대문구     4558
# 강북구      3379
# 금천구      3093
# 용산구      2685
# 광진구      2310
# 중구       1835
# 종로구      1419
# Name: count, dtype: int64

# %%
price['구'].value_counts(ascending = True)
# Out:
# 구
# 종로구      1419
# 중구       1835
# 광진구      2310
# 용산구      2685
# 금천구      3093
# 강북구      3379
# 서대문구     4558
# 관악구      4604
# 마포구      4849
# 성동구      4920
# 동작구      5031
# 중랑구      5089
# 동대문구     5496
# 은평구      5724
# 양천구      5793
# 영등포구     5998
# 서초구      6194
# 강남구      6723
# 강동구      6801
# 도봉구      6876
# 성북구      7386
# 송파구      7432
# 구로구      8491
# 강서구      9322
# 노원구     13909
# Name: count, dtype: int64

# %%
price['구'].value_counts().sort_index()
# Out:
# 구
# 강남구      6723
# 강동구      6801
# 강북구      3379
# 강서구      9322
# 관악구      4604
# 광진구      2310
# 구로구      8491
# 금천구      3093
# 노원구     13909
# 도봉구      6876
# 동대문구     5496
# 동작구      5031
# 마포구      4849
# 서대문구     4558
# 서초구      6194
# 성동구      4920
# 성북구      7386
# 송파구      7432
# 양천구      5793
# 영등포구     5998
# 용산구      2685
# 은평구      5724
# 종로구      1419
# 중구       1835
# 중랑구      5089
# Name: count, dtype: int64

# %%
price['구'].value_counts(normalize = True)

# %%
price['구'].value_counts(normalize = True) * 100

# %%
pd.crosstab(
    index = price['구'],
    columns = price['거래년도'],
    margins = True,
    margins_name = "합계",
    normalize = 'index'
)
# Out:
# 거래년도   2020   2021   2022
# 구
# 강남구   0.553  0.335  0.112
# 강동구   0.623  0.301  0.076
# 강북구   0.644  0.276  0.080
# 강서구   0.624  0.307  0.069
# 관악구   0.587  0.324  0.088
# 광진구   0.558  0.323  0.119
# 구로구   0.598  0.312  0.090
# 금천구   0.549  0.320  0.131
# 노원구   0.652  0.286  0.062
# 도봉구   0.666  0.276  0.059
# 동대문구  0.591  0.313  0.096
# 동작구   0.588  0.307  0.105
# 마포구   0.583  0.322  0.095
# 서대문구  0.602  0.317  0.081
# 서초구   0.537  0.354  0.109
# 성동구   0.618  0.309  0.073
# 성북구   0.612  0.320  0.068
# 송파구   0.623  0.287  0.090
# 양천구   0.602  0.326  0.072
# 영등포구  0.573  0.318  0.110
# 용산구   0.569  0.338  0.093
# 은평구   0.603  0.296  0.100
# 종로구   0.562  0.320  0.118
# 중구    0.560  0.334  0.106
# 중랑구   0.570  0.324  0.106
# 합계    0.602  0.310  0.087

# %%
# %whos
# Out:
# Variable   Type              Data/Info
# --------------------------------------
# addr       Series            0      서울특별시 강남구\n1    경기<...>  인천광역시 중구\ndtype: object
# birth      Series            0   1984-11-04\ndtype: datetime64[ns]
# chardet    module            <module 'chardet' from 'C<...>s\\chardet\\__init__.py'>
# cols       list              n=3
# df1        DataFrame                  아파트      시    구 <...>  1450000  \n3  1300000
# df2        DataFrame                     아파트      시   <...>80000  \n110650  458000
# dtGap      Timedelta         14039 days 19:23:46.053919
# file       BufferedReader    <_io.BufferedReader name=<...>ice_Seoul_2020_2022.csv'>
# fileName   str               APT_Price_Seoul_2020_2022.csv
# i          str               object
# joblib     module            <module 'joblib' from 'C:<...>es\\joblib\\__init__.py'>
# locs       Series            0         False\n1       <...>ngth: 139917, dtype: bool
# ...

# %%
# %whos - DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df1        DataFrame             아파트      시    구 <...>  1450000  \n3  1300000
# df2        DataFrame                아파트      시   <...>80000  \n110650  458000
# na         DataFrame        구분 항목    값\n0    A  a<...>N  b  2.6\n5  NaN  c  3.6
# price      DataFrame                       아파트   <...>139917 rows x 16 columns]

# %%
# %whos - module
# Out:
# Variable   Type      Data/Info
# ------------------------------
# chardet    module    <module 'chardet' from 'C<...>s\\chardet\\__init__.py'>
# joblib     module    <module 'joblib' from 'C:<...>es\\joblib\\__init__.py'>
# np         module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os         module    <module 'os' (frozen)>
# pd         module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged.csv',
#  'APT_Merged.xlsx',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'NA_Sample.xlsx',
#  'pivot_table.xlsx',
#  'test.csv',
#  'test.xlsx']

# %%
detail = pd.read_excel('APT_Detail_Seoul_2022.xlsx')

# %%
detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10290 entries, 0 to 10289
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아파트ID   10290 non-null  int64
#  1   아파트명    10290 non-null  object
#  2   지번주소    10290 non-null  object
#  3   위도      10290 non-null  float64
#  4   경도      10290 non-null  float64
#  5   동수      10290 non-null  int64
#  6   세대수     10290 non-null  int64
#  7   임대수     10290 non-null  int64
#  8   용적률     10290 non-null  int64
#  9   건폐율     10290 non-null  int64
#  10  주차대수    10290 non-null  int64
#  11  건설사     9746 non-null   object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 964.8+ KB

# %%
detail.head()
# Out:
#     아파트ID          아파트명                지번주소      위도       경도  동수   세대수  임대수
# 0  146479         YH빌리지  서울시 강남구 개포동 1237-8  37.478  127.047   1    16    0  \
# 1  119219     개포래미안포레스트    서울시 강남구 개포동 1282  37.478  127.054  31  2296  120
# 2  140057  개포비버리하임(도시형)  서울시 강남구 개포동 1193-5  37.475  127.049   2    29    0
# 3  107513       개포상지리츠빌   서울시 강남구 개포동 176-1  37.487  127.060   1    18    0
# 4    8928          개포자이    서울시 강남구 개포동 12-2  37.496  127.077   4   212    0
#
#    용적률  건폐율  주차대수        건설사
# 0  297   59     9  (주)세담종합건설
# 1  249   21  3961    삼성물산(주)
# 2  199   57    30   (주)덕인컨스텍
# 3  202   31    41    상지건영(주)
# 4  250   18   502    LG건설(주)

# %%
len(set(price['아파트']) & set(detail['아파트명']))
# Out:
# 2556

# %%
len(set(price['아파트']) - set(detail['아파트명']))
# Out:
# 4045

# %%
len(set(price['주소']) & set(detail['지번주소']))
# Out:
# 0

# %%
price['주소']
# Out:
# 0            서울특별시 종로구 필운동 254
# 1            서울특별시 종로구 사직동 9-1
# 2            서울특별시 종로구 내수동 167
# 3         서울특별시 종로구 내수동 110-15
# 4             서울특별시 종로구 내수동 95
#                   ...
# 139914    서울특별시 강동구 암사동 493-14
# 139915     서울특별시 강동구 암사동 414-2
# 139916       서울특별시 강동구 암사동 509
# 139917     서울특별시 강동구 성내동 452-2
# 139918       서울특별시 강동구 강일동 114
# Name: 주소, Length: 139917, dtype: object

# %%
detail['지번주소']
# Out:
# 0        서울시 강남구 개포동 1237-8
# 1          서울시 강남구 개포동 1282
# 2        서울시 강남구 개포동 1193-5
# 3         서울시 강남구 개포동 176-1
# 4          서울시 강남구 개포동 12-2
#                 ...
# 10285    서울시 중랑구 중화동 318-81
# 10286     서울시 중랑구 중화동 19-16
# 10287       서울시 중랑구 중화동 450
# 10288    서울시 중랑구 중화동 274-51
# 10289        서울시 중랑구 중화동 11
# Name: 지번주소, Length: 10290, dtype: object

# %%
price['주소'] = price['주소'].str.replace('특별', '')

# %%
len(set(price['주소']) & set(detail['지번주소']))
# Out:
# 6773

# %%
len(set(price['주소']) - set(detail['지번주소']))
# Out:
# 837

# %%
for i in range(10):
    np.random.seed(1)
    lotto = np.random.choice(a = range(1, 46), size = 6, replace = False) # 비복원 추출 False, 복원 추출 True
    lotto.sort()
    print(lotto)
# Out:
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]
# [ 3  4 22 23 31 42]

# %%
np.random.seed(seed = 1)

# %%
nums = np.random.choice(a = range(1, 5), size = 5, replace = True) ## 복원 추출
nums
# Out:
# array([2, 4, 1, 1, 4])

# %%
nums = pd.Series(nums)
nums
# Out:
# 0    2
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
nums.duplicated(keep = False)  ## 중복 Data 일 경우 True로
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
nums[nums.duplicated(keep = False)]  ## True인 항목만 남겨주는 코드
# Out:
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
nums.duplicated(keep = 'first')  ## 첫번째로 나온 것은 False, 중복으로 나오는 것은 True
                                ## nums.duplicated(keep = False) 와 차이 확인
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
nums[~nums.duplicated(keep = 'first')]   ## 중요, 복습합시다.
# Out:
# 0    2
# 1    4
# 2    1
# dtype: int32

# %%
locs = detail['지번주소'].duplicated(keep = False)
detail[locs]
# Out:
#        아파트ID                  아파트명                     지번주소      위도       경도
# 8       1303               개포주공6단지          서울시 강남구 개포동 185  37.489  127.070  \
# 9       1307               개포주공7단지          서울시 강남구 개포동 185  37.490  127.072
# 18       419                    대청           서울시 강남구 개포동 12  37.495  127.077
# 19       483                 대치2단지           서울시 강남구 개포동 12  37.495  127.075
# 474      724                현대6,7차         서울시 강남구 압구정동 456  37.530  127.029
# 475    27498         현대65동(대림아크로빌)         서울시 강남구 압구정동 456  37.532  127.032
# 956      902               주공고층3단지        서울시 강동구 둔촌동 174-1  37.524  127.139
# 959      901               주공저층2단지        서울시 강동구 둔촌동 174-1  37.523  127.136
# 1325  133403            미사아름채(도시형)       서울시 강동구 천호동 452-15  37.538  127.128
# 1326  133402           미사아름채(주상복합)       서울시 강동구 천호동 452-15  37.538  127.128
# 1539  145243   에피소드수유838(민간임대,도시형)          서울시 강북구 수유동 740  37.637  127.023
# ...

# %%
detail[locs].sort_values(by = ['지번주소'])
# Out:
#        아파트ID                  아파트명                     지번주소      위도       경도
# 18       419                    대청           서울시 강남구 개포동 12  37.495  127.077  \
# 19       483                 대치2단지           서울시 강남구 개포동 12  37.495  127.075
# 8       1303               개포주공6단지          서울시 강남구 개포동 185  37.489  127.070
# 9       1307               개포주공7단지          서울시 강남구 개포동 185  37.490  127.072
# 474      724                현대6,7차         서울시 강남구 압구정동 456  37.530  127.029
# 475    27498         현대65동(대림아크로빌)         서울시 강남구 압구정동 456  37.532  127.032
# 956      902               주공고층3단지        서울시 강동구 둔촌동 174-1  37.524  127.139
# 959      901               주공저층2단지        서울시 강동구 둔촌동 174-1  37.523  127.136
# 1325  133403            미사아름채(도시형)       서울시 강동구 천호동 452-15  37.538  127.128
# 1326  133402           미사아름채(주상복합)       서울시 강동구 천호동 452-15  37.538  127.128
# 1539  145243   에피소드수유838(민간임대,도시형)          서울시 강북구 수유동 740  37.637  127.023
# ...

# %%
detail[detail['지번주소'].duplicated(keep = 'first')].shape[0]
# Out:
# 29

# %%
detail = detail[~detail['지번주소'].duplicated(keep = 'first')]

# %%
detail
# Out:
#         아파트ID          아파트명                지번주소      위도       경도  동수   세대수
# 0      146479         YH빌리지  서울시 강남구 개포동 1237-8  37.478  127.047   1    16  \
# 1      119219     개포래미안포레스트    서울시 강남구 개포동 1282  37.478  127.054  31  2296
# 2      140057  개포비버리하임(도시형)  서울시 강남구 개포동 1193-5  37.475  127.049   2    29
# 3      107513       개포상지리츠빌   서울시 강남구 개포동 176-1  37.487  127.060   1    18
# 4        8928          개포자이    서울시 강남구 개포동 12-2  37.496  127.077   4   212
# ...       ...           ...                 ...     ...      ...  ..   ...
# 10285  104106            태솔  서울시 중랑구 중화동 318-81  37.597  127.075   1    19
# 10286  102174           한솔e   서울시 중랑구 중화동 19-16  37.603  127.084   2    35
# 10287     824            한신     서울시 중랑구 중화동 450  37.597  127.082   9  1544
# 10288   18519            한영  서울시 중랑구 중화동 274-51  37.606  127.082   4    72
# 10289  105704         현대휴앤미      서울시 중랑구 중화동 11  37.603  127.085   2    34
#
#        임대수  용적률  건폐율  주차대수                  건설사
# ...

# %%
pd.merge(
    left = price,
    right = detail,
    how = 'inner',
    left_on = '주소',
    right_on = '지번주소'
)
# Out:
#                 아파트      시    구    동     지번  건축년도        거래일    전용면적   층
# 0       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2020-01-03  111.97   6  \
# 1       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2020-02-21  108.95   7
# 2       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2021-10-25  111.97   8
# 3             세종로대우  서울특별시  종로구  내수동    167  1994 2020-01-06  109.91  11
# 4             세종로대우  서울특별시  종로구  내수동    167  1994 2020-02-20   66.96  12
# ...             ...    ...  ...  ...    ...   ...        ...     ...  ..
# 132808        더메종건대  서울특별시  광진구  화양동   23-5  2022 2022-12-23   17.78  12
# 132809     삼영N-CITY  서울특별시  은평구  응암동  96-19  2015 2022-12-24   45.91   6
# 132810        길훈로즈빌  서울특별시  양천구  신정동   1297  2002 2022-12-16   84.95  14
# 132811        길훈로즈빌  서울특별시  양천구  신정동   1297  2002 2022-12-19   84.95  14
# 132812    강동리버스트4단지  서울특별시  강동구  강일동    114  2020 2022-12-29   59.99   7
#
#           거래금액  ...               지번주소      위도       경도  동수   세대수  임대수  용적률
# ...

# %%
detail = detail.rename(columns = {'지번주소': '주소'})

# %%
detail
# Out:
#         아파트ID          아파트명                  주소      위도       경도  동수   세대수
# 0      146479         YH빌리지  서울시 강남구 개포동 1237-8  37.478  127.047   1    16  \
# 1      119219     개포래미안포레스트    서울시 강남구 개포동 1282  37.478  127.054  31  2296
# 2      140057  개포비버리하임(도시형)  서울시 강남구 개포동 1193-5  37.475  127.049   2    29
# 3      107513       개포상지리츠빌   서울시 강남구 개포동 176-1  37.487  127.060   1    18
# 4        8928          개포자이    서울시 강남구 개포동 12-2  37.496  127.077   4   212
# ...       ...           ...                 ...     ...      ...  ..   ...
# 10285  104106            태솔  서울시 중랑구 중화동 318-81  37.597  127.075   1    19
# 10286  102174           한솔e   서울시 중랑구 중화동 19-16  37.603  127.084   2    35
# 10287     824            한신     서울시 중랑구 중화동 450  37.597  127.082   9  1544
# 10288   18519            한영  서울시 중랑구 중화동 274-51  37.606  127.082   4    72
# 10289  105704         현대휴앤미      서울시 중랑구 중화동 11  37.603  127.085   2    34
#
#        임대수  용적률  건폐율  주차대수                  건설사
# ...
